# %% [markdown]
# <a href="https://colab.research.google.com/github/satyakrupamallipudi-byte/Team4-SLM-Learning-Journey-/blob/main/DAY_3_TASK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multiplication_table(num):
    for i in range(1, 6):
        print(f"{num} x {i} = {num * i}")

number = int(input("Enter a number: "))
multiplication_table(number)
# Out:
# Enter a number: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25

# %%
data_store = []

data_store.append("Python")
data_store.append("Java")
data_store.append("C")

print("Stored Data:", data_store)
# Out:
# Stored Data: ['Python', 'Java', 'C']

# %%
students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")
    students.append(name)

print("Student List:", students)
# Out:
# Enter number of students: 3
# Enter student name: M SATYA
# Enter student name: SRI LAXMI
# Enter student name: SRIDEVI
# Student List: ['M SATYA ', 'SRI LAXMI ', 'SRIDEVI']

# %%
students = ["Ravi", "Sita", "Rahul", "Priya"]

print("Student Names:")
for student in students:
    print(student)
# Out:
# Student Names:
# Ravi
# Sita
# Rahul
# Priya

# %%
def add_numbers(a, b):
    return a + b

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = add_numbers(num1, num2)
print("Sum =", result)
# Out:
# Enter first number: 23
# Enter second number: 24
# Sum = 47

# %%
def display_student(name, roll_no, course):
    print("Student Details")
    print("Name:", name)
    print("Roll No:", roll_no)
    print("Course:", course)

display_student("Satyakrupa", 101, "Python")
# Out:
# Student Details
# Name: Satyakrupa
# Roll No: 101
# Course: Python
